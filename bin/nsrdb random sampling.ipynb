# %%
import numpy as np
import os
import pandas as pd

cwd = os.getcwd()

def get_gid(meta):
    """
    Extract random gid from nsrdb ensuring samples are randomly sampled from available states and counties
    
    Parameters
    ----------
    meta : 'pandas.DataFrame'
        DataFrame of meta data from which to randomly samples pixels

    Returns
    -------
    gid : 'int'
        Selected gid
    """
    if len(meta['state'].unique()) > 1:
        state = np.random.choice(meta['state'].unique(), 1)[0]
        meta = meta.loc[meta['state'] == state]

    if len(meta['county'].unique()) > 1:
        county = np.random.choice(meta['county'].unique(), 1)[0]
        meta = meta.loc[meta['county'] == county]
    
    gid = np.random.choice(meta['gid'].values, 1)[0]
    return gid


def sample_nsrdb(meta, samples):
    """
    Randomly sample from nsrdb meta data
    Samples are selected from available countries, states, or counties
    
    Parameters
    ----------
    meta : 'pandas.DataFrame'
        DataFrame of meta data from which to randomly samples pixels
    samples : 'int'
        Number of samples to select

    Returns
    -------
    'pandas.DataFrame'
        Meta data for selected pixels
    """
    gids = []
    if len(meta['country'].unique()) > 1:
        countries = np.random.choice(meta['country'].unique(), samples)
        for country in countries:
            country_meta = meta.loc[meta['country'] == country]
            gids.append(get_gid(country_meta))      
    elif len(meta['state'].unique()) > 1:
        states = np.random.choice(meta['state'].unique(), samples)
        for state in states:
            state_meta = meta.loc[meta['state'] == state]
            gids.append(get_gid(state_meta))
    elif len(meta['county'].unique()) > 1:
        counties = np.random.choice(meta['county'].unique(), samples)
        for county in counties:
            county_meta = meta.loc[meta['county'] == county]
            gids.append(get_gid(county_meta))
    else:
        gids = np.random.choice(meta['gid'], samples)
        
    return meta.loc[gids]

# %% [markdown]
# # Randomly sample from nsrdb

# %%
path = os.path.join(cwd, 'nsrdb_meta.csv')
meta = pd.read_csv(path)
meta['gid'] = np.arange(len(meta))

# %%
countries = sample_nsrdb(meta, 5)
countries
# Out:
#          latitude  longitude  elevation  timezone                  country  \
# 1572572     18.09     -63.02       1.00        -4                St-Martin
# 1734380     46.97     -56.34       1.00        -3  St. Pierre and Miquelon
# 1349196     18.37     -70.38     457.24        -4           Dominican Rep.
# 1229219     22.37     -74.06       4.72        -5                  Bahamas
# 1318590     19.37     -71.30     478.85        -4           Dominican Rep.
#
#                                   state                   county urban  \
# 1572572  MAF-00 (St. Martin aggregation                     None  None
# 1734380  SPM-00 (St. Pierre and Miquelo                     None  None
# 1349196                         Peravia                     Baní  None
# 1229219    BHS-00 (Bahamas aggregation)                     None  None
# 1318590              Santiago Rodríguez  San Ignacio de Sabaneta  None
#
#          population  landcover      gid
# 1572572        3816        210  1572572
# 1734380          10        210  1734380
# 1349196         411         40  1349196
# 1229219           2         40  1229219
# 1318590         610         30  1318590

# %%
US = meta.loc[meta['country'] == 'United States']
states = sample_nsrdb(US, 5)
states
# Out:
#          latitude  longitude  elevation  timezone        country  \
# 1129606     38.93     -77.10      75.75        -5  United States
# 930832      37.65     -85.66     261.04        -5  United States
# 762566      47.37     -93.38     414.44        -6  United States
# 97624       48.05    -124.38     209.80        -8  United States
# 283316      47.05    -113.34    1443.00        -7  United States
#
#                         state                county             urban  \
# 1129606  District of Columbia  District of Columbia  Washington, D.C.
# 930832               Kentucky                 Larue              None
# 762566              Minnesota                Itasca              None
# 97624              Washington               Clallam              None
# 283316                Montana              Missoula              None
#
#          population  landcover      gid
# 1129606       20118         70  1129606
# 930832           37         50   930832
# 762566          118         50   762566
# 97624            40        100    97624
# 283316            0        150   283316

# %%
CO = conus.loc[US['state'] == 'Colorado']
counties = sample_nsrdb(CO, 5)
counties
# Out:
#         latitude  longitude  elevation  timezone        country     state  \
# 408282     38.13    -107.62    2663.30        -7  United States  Colorado
# 467155     37.89    -105.14    2678.44        -7  United States  Colorado
# 542324     38.49    -102.26    1245.44        -7  United States  Colorado
# 525165     40.81    -102.90    1147.80        -7  United States  Colorado
# 410110     40.01    -107.54    2404.08        -7  United States  Colorado
#
#             county urban  population  landcover     gid
# 408282       Ouray  None           0         70  408282
# 467155    Huerfano  None           1         70  467155
# 542324       Kiowa  None           0        130  542324
# 525165       Logan  None           4         14  525165
# 410110  Rio Blanco  None           6         70  410110

# %%
Denver = CO.loc[CO['county'] == 'Denver']
pixels = sample_nsrdb(Denver, 5)
pixels
# Out:
#         latitude  longitude  elevation  timezone        country     state  \
# 469107     39.61    -105.06    1685.28        -7  United States  Colorado
# 469648     39.65    -105.06    1672.64        -7  United States  Colorado
# 480934     39.85    -104.62    1618.84        -7  United States  Colorado
# 472706     39.77    -104.94    1596.64        -7  United States  Colorado
# 469107     39.61    -105.06    1685.28        -7  United States  Colorado
#
#         county   urban  population  landcover     gid
# 469107  Denver  Denver       15089         70  469107
# 469648  Denver  Denver       22076         70  469648
# 480934  Denver    None           2         30  480934
# 472706  Denver  Denver       27744        190  472706
# 469107  Denver  Denver       15089         70  469107
